# %%
import pandas as pd

# %%
path = "input/Experiment1.xlsx"

# %%
df = pd.read_excel(path)
df
# Out:
#     Procedure  Statement producer statement Consumer Statements   cost(s)  \
# 0           1          1                 {}               {2,3}  0.114026
# 1           1          2                {1}                 {3}  0.078130
# 2           1          3              {1,2}                 {7}  0.200103
# 3           1          4                 {}               {5,6}  0.240052
# 4           1          5                {4}                 {6}  0.080120
# 5           1          6              {4,5}                 {7}  0.255250
# 6           1          7              {3,6}                  {}  0.300235
# 7           2          8                 {}              {9,10}  0.170942
# 8           2          9                {8}                {10}  0.078130
# 9           2         10              {8,9}                {14}  0.125236
# 10          2         11                 {}             {12,13}  0.240052
# 11          2         12               {11}                {13}  0.080120
# ...
